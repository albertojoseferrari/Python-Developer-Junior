# %% [markdown]
# # CLASE 4 - DICCIONARIOS

# %% [markdown]
# 1.   Sea el siguiente diccionario:
# s= {'fruta':' Peras', 'cantidad': 10, 'precio': 35.10}
#
# *   Mostrar la fruta y la cantidad
# *   Mostrar el precio
# *   Modificar el precio por el valor de 75
# *   Agregar un par clave-valor con la fecha de compra
# *   Mostrar las claves del diccionario utilizando el for
# *   Mostrar el par clave-valor del diccionario
# *   Pasar el diccionario a una lista
# *   Eliminar un elemento del diccionario

# %%
s= {'fruta': 'Peras', 'cantidad': 10, 'precio': 35.10}
print("La fruta es", s["fruta"], "y la cantidad es", s["cantidad"])
print("El precio es", s["precio"])
s["precio"]=75
s["fecha de compra"]="6-6-23"
print("Las claves del diccionario son:")
for i in s:
  print(i)
print("Los pares clave-valor del diccionario son:")
for i in s.items():
  print(i)
lista1=list(s)
lista2=list(s.values())
print(lista1)
print(lista2)
lista=list(zip(lista1,lista2))
print("El diccionario pasado a una lista es:")
print(lista)
s.pop("cantidad")
print("El diccionario sin la cantidad es:")
print(s)
# Out:
# La fruta es Peras y la cantidad es 10
# El precio es 35.1
# Las claves del diccionario son:
# fruta
# cantidad
# precio
# fecha de compra
# Los pares clave-valor del diccionario son:
# ('fruta', 'Peras')
# ('cantidad', 10)
# ('precio', 75)
# ('fecha de compra', '6-6-23')
# ['fruta', 'cantidad', 'precio', 'fecha de compra']
# ['Peras', 10, 75, '6-6-23']
# El diccionario pasado a una lista es:
# [('fruta', 'Peras'), ('cantidad', 10), ('precio', 75), ('fecha de compra', '6-6-23')]
# El diccionario sin la cantidad es:
# {'fruta': 'Peras', 'precio': 75, 'fecha de compra': '6-6-23'}

# %% [markdown]
# Solución de Manu:

# %%
s = {'fruta':' Peras', 'cantidad': 10, 'precio': 35.10}

a = str(input(" ingrese fecha de compra    "))

print ()

print(s)

print ()

print ("fruta:",s["fruta"], ", cantidad:", s["cantidad"])

print ("precio:", (s["precio"]))

s["precio"] = 75

print ("nuevo precio:", (s["precio"]))

s["fecha"] = a

print ("fecha de la compra:", (s["fecha"]))

print()

for i in (s.keys()):
 print(i)

print()

for i in (s.items()):
 print(i)

g = list(s)
h = list(s.values())
print()

print(g)
print(h)
print()

w = s.pop("cantidad")

print(s)

print()

print(w)

print()

del (g[0:2])

print(g)

print()
# Out:
#  ingrese fecha de compra    6-6-23
#
# {'fruta': ' Peras', 'cantidad': 10, 'precio': 35.1}
#
# fruta:  Peras , cantidad: 10
# precio: 35.1
# nuevo precio: 75
# fecha de la compra: 6-6-23
#
# fruta
# cantidad
# precio
# fecha
#
# ('fruta', ' Peras')
# ('cantidad', 10)
# ('precio', 75)
# ('fecha', '6-6-23')
#
# ['fruta', 'cantidad', 'precio', 'fecha']
# [' Peras', 10, 75, '6-6-23']
#
# {'fruta': ' Peras', 'precio': 75, 'fecha': '6-6-23'}
#
# 10
#
# ['precio', 'fecha']

# %% [markdown]
# Solución de Damián:

# %%
s= {'fruta':'Peras', 'cantidad': 10, 'precio': 35.10} # declara el diccionario
print("Fruta:", s["fruta"], ", Cantidad :", s["cantidad"]) # Muestra fruta y cantidad
print("El precio es:", s["precio"]) # muestra el precio solamente
s["precio"]= 75 # cambia el valor del precio
print("----------------") # linea vacia
print("El nuevo precio es:", s["precio"])
fecha= str(input("Ingrese la fecha de compra separada por guiones:"))
s["fecha"]= fecha # agrega un nuevo elemento al diccionario
print("----------------") # linea vacia
for clave in s: # muestra solo las claves
    print(clave)
print("----------------") # linea vacia
for clave,valor in s.items(): # muestra cada clave y valor del diccionario
    print(clave, valor)
print("----------------") # linea vacia
print(list(s)) # muestra el diccionario como lista
print("----------------") # linea vacia
del s["precio"] # elimina un elemento del diccionario
print(s)
# Out:
# Fruta: Peras , Cantidad : 10
# El precio es: 35.1
# ----------------
# El nuevo precio es: 75
# Ingrese la fecha de compra separada por guiones:6-6-23
# ----------------
# fruta
# cantidad
# precio
# fecha
# ----------------
# fruta Peras
# cantidad 10
# precio 75
# fecha 6-6-23
# ----------------
# ['fruta', 'cantidad', 'precio', 'fecha']
# ----------------
# {'fruta': 'Peras', 'cantidad': 10, 'fecha': '6-6-23'}

# %% [markdown]
# 2. Definir un diccionario con 4 elementos.  Las claves son clave1, clave2, clave3 y clave4. Y los valores correspondientes a cada clave son: un valor entero, un valor booleano, un string y una lista que contiene los números desde el 1 al 4.
#
# a) Mostrar a que tipo corresponde la estructura completa.
#
# b) Mostrar cada uno de sus valores usando sus claves
#
# c) Mostrar que tipo de dato tiene cada valor de clave
#
# d) Agregar un elemento más al diccionario
#
# e) Ingresar por teclado un dato y determinar si existe una clave que coincida con alguna clave del diccionario. Si se encuentra mostrar el valor asociado
#
# f) Copiar en forma “superficial” el diccionario y modificar el primer valor de clave. Observar que sucede con el diccionario original.
# Poner el valor cero a todos los valores del diccionario
#
# g) Recorrer y mostrar todos los elementos clave-valor del diccionario.
# Ingresar por teclado un dato y  eliminar del diccionario dicho dato si se encuentra dentro del diccionario.
#
# h) Eliminar todos los elementos del diccionario

# %%
diccio={"clave1": 18, "clave2": False, "clave3": "hola", "clave4": [1,2,3,4]}
print("a)")
print(type(diccio))
print("b)")
for i in diccio:
  print(diccio[i])
print("c)")
for i in diccio.values():
  print(type(i))
print("d)")
diccio["clave5"]=5.5
print(diccio)
print("e)")
clave=input("Ingrese una clave: ")
bandera=0
for i in diccio:
  if i==clave:
    print(f"El valor asociado a la clave ingresada es {diccio[i]}.")
    bandera=1
if bandera==0:
  print("La clave ingresada no se encuentra en el diccionario.")
print("f)")
diccio_copia= diccio.copy()
diccio_copia["clave1"]=10
print(f"El diccionario original es {diccio}.")
for i in diccio_copia:
  diccio_copia[i]=0
print(f"El nuevo diccionario es {diccio_copia}.")
print("g)")
for i in diccio.items():
  print(i)
print("[1]: Entero")
print("[2]: Booleano")
print("[3]: String")
print("[4]: Flotante")
print("[5]: Lista")
numero=int(input("Ingrese el tipo de dato a eliminar: "))
if numero==1:
  dato=int(input("Ingrese el dato a eliminar: "))
elif numero==2:
  dato=bool(input("Ingrese el dato a eliminar: "))
elif numero==3:
  dato=input("Ingrese el dato a eliminar: ")
elif numero==4:
  dato=float(input("Ingrese el dato a eliminar: "))
elif numero==5:
  cantidad=int(input("Ingrese la cantidad de elementos de la lista: "))
  dato=[]
  for i in range(cantidad):
    elemento=int(input(f"Ingrese el {i+1}° elemento de la lista: "))
    dato.append(elemento)
bandera=0
for i in diccio:
  if diccio[i]==dato:
    clave=i
    bandera=1
diccio.pop(clave)
if bandera==1:
  print(f"El diccionario sin el dato ingresado es {diccio}.")
else:
  print("El dato ingresado no se encontró.")
print("h)")
diccio.clear()
print(f"El diccionario con todos los elementos eliminados es {diccio}.")
# Out:
# a)
# <class 'dict'>
# b)
# 18
# False
# hola
# [1, 2, 3, 4]
# c)
# <class 'int'>
# <class 'bool'>
# <class 'str'>
# <class 'list'>
# d)
# {'clave1': 18, 'clave2': False, 'clave3': 'hola', 'clave4': [1, 2, 3, 4], 'clave5': 5.5}
# e)
# Ingrese una clave: clave3
# El valor asociado a la clave ingresada es hola.
# f)
# El diccionario original es {'clave1': 18, 'clave2': False, 'clave3': 'hola', 'clave4': [1, 2, 3, 4], 'clave5': 5.5}.
# El nuevo diccionario es {'clave1': 0, 'clave2': 0, 'clave3': 0, 'clave4': 0, 'clave5': 0}.
# g)
# ('clave1', 18)
# ('clave2', False)
# ('clave3', 'hola')
# ('clave4', [1, 2, 3, 4])
# ('clave5', 5.5)
# [1]: Entero
# [2]: Booleano
# [3]: String
# [4]: Flotante
# [5]: Lista
# Ingrese el tipo de dato a eliminar: 5
# Ingrese la cantidad de elementos de la lista: 4
# Ingrese el 1° elemento de la lista: 1
# Ingrese el 2° elemento de la lista: 2
# Ingrese el 3° elemento de la lista: 3
# Ingrese el 4° elemento de la lista: 4
# ...

# %% [markdown]
# 3. Definir un diccionario y luego cargar N elementos. N se ingresa por teclado. Luego:
#
# •	Recorrer el diccionario mostrando el par clave-valor
#
# •	Devolver el número de elementos del diccionario
#
# •	Recorrer el diccionario mostrando las claves
#
# •	Insertar un nuevo elemento en el diccionario
#
# •	Copiar un diccionario a otro vacío
#
# •	Eliminar el diccionario original

# %%
diccio={}
N=int(input("Ingrese la cantidad de elementos del diccionario: "))
for i in range(N):
  print("[1]: Entero")
  print("[2]: Booleano")
  print("[3]: String")
  print("[4]: Flotante")
  numero=int(input(f"Ingrese el tipo de la {i+1}° clave: "))
  if numero==1:
    clave=int(input(f"Ingrese la {i+1}° clave: "))
  elif numero==2:
    clave=bool(input(f"Ingrese la {i+1}° clave: "))
  elif numero==3:
    clave=input(f"Ingrese la {i+1}° clave: ")
  elif numero==4:
    clave=float(input(f"Ingrese la {i+1}° clave: "))
  print("[1]: Entero")
  print("[2]: Booleano")
  print("[3]: String")
  print("[4]: Flotante")
  print("[5]: Lista")
  numero=int(input(f"Ingrese el tipo del {i+1}° valor: "))
  if numero==1:
    valor=int(input(f"Ingrese el {i+1}° valor "))
  elif numero==2:
    valor=bool(input(f"Ingrese el {i+1}° valor: "))
  elif numero==3:
    valor=input(f"Ingrese el {i+1}° valor: ")
  elif numero==4:
    valor=float(input(f"Ingrese el {i+1}° valor: "))
  elif numero==5:
    cantidad=int(input("Ingrese la cantidad de elementos de la lista: "))
    valor=[]
    for j in range(cantidad):
      elemento=int(input(f"Ingrese el {j+1}° elemento de la lista: "))
      valor.append(elemento)
  diccio[clave]=valor
print("Los pares clave-valor del diccionario son:")
for i in diccio.items():
  print(i)
print(f"La cantidad de elementos del diccionario es {len(diccio)}.")
print("Las claves del diccionario son:")
for i in diccio:
  print(i)
print("[1]: Entero")
print("[2]: Booleano")
print("[3]: String")
print("[4]: Flotante")
numero=int(input(f"Ingrese el tipo de la nueva clave: "))
if numero==1:
  clave=int(input(f"Ingrese la nueva clave: "))
elif numero==2:
  clave=bool(input(f"Ingrese la nueva clave: "))
elif numero==3:
  clave=input(f"Ingrese la nueva clave: ")
elif numero==4:
  clave=float(input(f"Ingrese la nueva clave: "))
print("[1]: Entero")
print("[2]: Booleano")
print("[3]: String")
print("[4]: Flotante")
print("[5]: Lista")
numero=int(input(f"Ingrese el tipo del nuevo valor: "))
if numero==1:
  valor=int(input(f"Ingrese el nuevo valor "))
elif numero==2:
  valor=bool(input(f"Ingrese el nuevo valor: "))
elif numero==3:
  valor=input(f"Ingrese el nuevo valor: ")
elif numero==4:
  valor=float(input(f"Ingrese el nuevo valor: "))
elif numero==5:
  cantidad=int(input("Ingrese la cantidad de elementos de la lista: "))
  valor=[]
  for j in range(cantidad):
    elemento=int(input(f"Ingrese el {j+1}° elemento de la lista: "))
    valor.append(elemento)
diccio[clave]=valor
print(f"El nuevo diccionario es {diccio}.")
print(diccio)
diccio_copia= diccio.copy()
diccio.clear()
print(f"El diccionario original ahora es {diccio}.")
print(f"El diccionario nuevo es {diccio_copia}.")
# Out:
# Ingrese la cantidad de elementos del diccionario: 4
# [1]: Entero
# [2]: Booleano
# [3]: String
# [4]: Flotante
# Ingrese el tipo de la 1° clave: 1
# Ingrese la 1° clave: 18
# [1]: Entero
# [2]: Booleano
# [3]: String
# [4]: Flotante
# [5]: Lista
# Ingrese el tipo del 1° valor: 1
# Ingrese el 1° valor 10
# [1]: Entero
# [2]: Booleano
# [3]: String
# [4]: Flotante
# Ingrese el tipo de la 2° clave: 2
# Ingrese la 2° clave: True
# [1]: Entero
# [2]: Booleano
# [3]: String
# [4]: Flotante
# [5]: Lista
# Ingrese el tipo del 2° valor: 2
# Ingrese el 2° valor: False
# [1]: Entero
# [2]: Booleano
# [3]: String
# [4]: Flotante
# Ingrese el tipo de la 3° clave: 3
# Ingrese la 3° clave: hola
# [1]: Entero
# [2]: Booleano
# [3]: String
# [4]: Flotante
# [5]: Lista
# Ingrese el tipo del 3° valor: 3
# Ingrese el 3° valor: chau
# [1]: Entero
# [2]: Booleano
# [3]: String
# [4]: Flotante
# Ingrese el tipo de la 4° clave: 4
# Ingrese la 4° clave: 5.5
# [1]: Entero
# [2]: Booleano
# [3]: String
# ...

# %% [markdown]
# Solución de Damián:

# %%
dicc={}
n= int(input("Ingrese la cantidad de elementos a cargar: ")) # pide la cantidad de elementos a agregar
for i in range(n): # pide la cantidad de n veces, la clave y el valor del elemento actual
    clave= input("Ingrese la clave del elemento nº" + str(i+1) + ": ")
    valor= input("Ingrese el valor del elemento nº" + str(i+1) + ": ")
    dicc[clave]= valor # agrega el elemento al diccionario
print(dicc)
print() # linea vacia
print("El diccionario tiene", len(dicc), "elementos")
print() # linea vacia
for clave in dicc: # muestra solo las claves
    print(clave)
print() # linea vacia
dicc["clavenueva"]= n + 1
dicc_copia= dicc.copy() # copia un diccionario a otro
print("Diccionario dicc:" ,dicc)
print("Diccionario dicc_copia:" ,dicc_copia)
del dicc # elimina el diccionario
print("El Diccionario dicc ha sido eliminado:")
# Out:
# Ingrese la cantidad de elementos a cargar: 3
# Ingrese la clave del elemento nº1: hola
# Ingrese el valor del elemento nº1: 8
# Ingrese la clave del elemento nº2: 15
# Ingrese el valor del elemento nº2: True
# Ingrese la clave del elemento nº3: gato
# Ingrese el valor del elemento nº3: perro
# {'hola': '8', '15': 'True', 'gato': 'perro'}
#
# El diccionario tiene 3 elementos
#
# hola
# 15
# gato
#
# Diccionario dicc: {'hola': '8', '15': 'True', 'gato': 'perro', 'clavenueva': 4}
# Diccionario dicc_copia: {'hola': '8', '15': 'True', 'gato': 'perro', 'clavenueva': 4}
# El Diccionario dicc ha sido eliminado:

# %% [markdown]
# Solución de Martín:

# %%
# 3 otro
myDict = {}
claseDato = [None, int, str, bool, float, dict, set, list, tuple]

def crearLisTup(tipo):
  lista =[]
  elementos = int(input(f'¿Cuántos elementos tendrá la lista/tupla ?: '))
  for ele in range(elementos):
    print(f'El {ele+1}° elemento de la lista/tupla será de ¿Qué tipo?:\n0-None\n1-Intenger\n2-String\n3-Booleno\n4-Float\n5-Lista\n6-Tupla\n7-Diccionario')
    tipo = int(input())
    if tipo <5:
      valor = claseDato[tipo](input(f'Ingresa el valor: '))
      lista.append(valor)
    elif tipo > 4 and tipo <7:
      crearLisTup(tipo)
    else:
      crearDic()
  if tipo == 6:
    return tuple(lista)
  else:
    return lista

def crearDic (diccio):
  diccio = {}
  pares = int(input('¿Cuántos elementos tendrá el diccionario?: '))
  for par in range(pares):
    print(par+1,'º clave:')
    print('La clave será de ¿Qué tipo?:\n1-Intenger\n2-String\n3-Booleno\n4-Float')
    tipo = int(input())
    clave = claseDato[tipo](input('Ingresa el nombre de la clave: '))
    print('El valor será de ¿Qué tipo?:\n0-None\n1-Intenger\n2-String\n3-Booleno\n4-Float\n5-Lista\n6-Tupla\n7-Diccionario')
    tipo = int(input())
    if tipo <5:
      valor = claseDato[tipo](input(f'Ingresa el valor para la clave {clave}: '))
      diccio.setdefault(clave, valor)
    elif tipo > 4 and tipo <7:
      diccio.setdefault(clave, crearLisTup(tipo))
    else:
      diccio[clave]=crearDic(clave)
  return diccio

print(crearDic(myDict))
# Out:
# ¿Cuántos elementos tendrá el diccionario?: 3
# 1 º clave:
# La clave será de ¿Qué tipo?:
# 1-Intenger
# 2-String
# 3-Booleno
# 4-Float
# 1
# Ingresa el nombre de la clave: 18
# El valor será de ¿Qué tipo?:
# 0-None
# 1-Intenger
# 2-String
# 3-Booleno
# 4-Float
# 5-Lista
# 6-Tupla
# 7-Diccionario
# 5
# ¿Cuántos elementos tendrá la lista/tupla ?: 2
# El 1° elemento de la lista/tupla será de ¿Qué tipo?:
# 0-None
# 1-Intenger
# 2-String
# 3-Booleno
# 4-Float
# 5-Lista
# 6-Tupla
# 7-Diccionario
# 1
# Ingresa el valor: 1
# El 2° elemento de la lista/tupla será de ¿Qué tipo?:
# 0-None
# 1-Intenger
# 2-String
# 3-Booleno
# 4-Float
# 5-Lista
# 6-Tupla
# 7-Diccionario
# 2
# Ingresa el valor: hola
# 2 º clave:
# La clave será de ¿Qué tipo?:
# 1-Intenger
# 2-String
# 3-Booleno
# 4-Float
# 2
# Ingresa el nombre de la clave: chau
# El valor será de ¿Qué tipo?:
# 0-None
# 1-Intenger
# 2-String
# 3-Booleno
# 4-Float
# 5-Lista
# 6-Tupla
# 7-Diccionario
# 3
# ...

# %% [markdown]
# 4. Cargar un Diccionario con el nombre de  tres alumnos y las notas de tres parciales.
#
# •	Validar las notas al cargar [0,10]
#
# •	Mostrar el nombre de cada alumno y SOLO la mayor nota de los tres parciales.
#
# •	Mostrar el nombre de cada alumno y el promedio de las tres notas de los tres parciales.
#
# •	Cargar desde el teclado dos listas con valores reales, lista1 y lista2. Luego incluir en un diccionario las listas como valores para las claves : 'UNO' y 'DOS'

# %%
estudiantes={}
for i in range(3):
  clave=input(f"Ingrese el nombre del {i+1}° estudiante: ")
  valor=[]
  for j in range(3):
    bandera=0
    while bandera==0:
      nota=float(input(f"Ingrese la {j+1}° nota del estudiante {clave}: "))
      if nota < 0 or nota > 10:
        print("Ingrese una nota válida entre 0 y 10.")
      else:
        bandera=1
    valor.append(nota)
  estudiantes[clave]=valor
for i in estudiantes:
  print("La mayor nota del estudiante", i, "es", max(estudiantes[i]))
for i in estudiantes:
  suma=0
  for j in estudiantes[i]:
    suma+=j
  print("El promedio del estudiante", i, "es", suma/3)

diccionario={}
n1=int(input("Ingrese la cantidad de elementos de la lista 1: "))
lista1=[]
for i in range(n1):
  elemento=float(input(f"Ingrese el {i+1}° elemento de la lista 1: "))
  lista1.append(elemento)
n2=int(input("Ingrese la cantidad de elementos de la lista 2: "))
lista2=[]
for i in range(n2):
  elemento=float(input(f"Ingrese el {i+1}° elemento de la lista 2: "))
  lista2.append(elemento)
diccionario["UNO"]=lista1
diccionario["DOS"]=lista2
print(diccionario)
# Out:
# Ingrese el nombre del 1° estudiante: Alberto
# Ingrese la 1° nota del estudiante Alberto: 11
# Ingrese una nota válida entre 0 y 10.
# Ingrese la 1° nota del estudiante Alberto: -1
# Ingrese una nota válida entre 0 y 10.
# Ingrese la 1° nota del estudiante Alberto: 10
# Ingrese la 2° nota del estudiante Alberto: 0
# Ingrese la 3° nota del estudiante Alberto: 6
# Ingrese el nombre del 2° estudiante: Marina
# Ingrese la 1° nota del estudiante Marina: 9
# Ingrese la 2° nota del estudiante Marina: 6.5
# Ingrese la 3° nota del estudiante Marina: 8.5
# Ingrese el nombre del 3° estudiante: Jorge
# Ingrese la 1° nota del estudiante Jorge: 2
# Ingrese la 2° nota del estudiante Jorge: 8
# Ingrese la 3° nota del estudiante Jorge: 5
# La mayor nota del estudiante Alberto es 10.0
# La mayor nota del estudiante Marina es 9.0
# La mayor nota del estudiante Jorge es 8.0
# El promedio del estudiante Alberto es 5.333333333333333
# El promedio del estudiante Marina es 8.0
# ...

# %% [markdown]
# Solución de Damián:

# %%
alumnos={}
valido=False
for i in range(3):
    clave= str(input("Ingrese el nombre del alumno nº" + str(i+1) + ": "))

    while not valido:
        nota1= float(input("Ingrese 1ª nota del alumno " + clave + ": "))
        nota2= float(input("Ingrese 2ª nota del alumno " + clave + ": "))
        nota3= float(input("Ingrese 3ª nota del alumno " + clave + ": "))
        if 0 <= nota1 <= 10 and 0 <= nota2 <= 10 and 0 <= nota3 <= 10: # valida que la nota este entre 0 y 10
            valido= True
        else:
            print("Ingrese las 3 notas validas de 0 a 10")
    notas=[nota1,nota2,nota3]
    prom_nota=(nota1 + nota2 + nota3)/3
    max_nota = max(notas) # calcula el maximo de las 3 notas
    alumnos[clave]= {"Mayor":max_nota, "Promedio":prom_nota} # agrega el elemento notas y la mayor de ellas al diccionario

    valido=False # una vez que agrega el elemento vuelve a poner valido como falso para que funcione el proximo while
print() # linea vacia
for clave in alumnos:
    print(clave)
print() # linea vacia
for alumno, detalles in alumnos.items():
    print("Alumno: ", alumno)
    print("Mejor nota: ", detalles["Mayor"])
    print("Promedio de las 3 notas: ", detalles["Promedio"])

print() # linea vacia
lista1=[]
lista2=[]
n= int(input("Ingrese la cantidad de elementos que tendra la lista 1: ")) # ingresa la cantidad de elementos a agregar
for i in range(n):
    elemento= float(input("Ingrese el elemento para la lista 1: "))
    lista1.append(elemento) # carga la lista

n= int(input("Ingrese la cantidad de elementos que tendra la lista 2: ")) # ingresa la cantidad de elementos a agregar
for i in range(n):
    elemento= float(input("Ingrese el elemento para la lista 2: "))
    lista2.append(elemento) # carga la lista

diccionario={"UNO":lista1, "DOS":lista2}
print("Diccionario obtenido:", diccionario)
# Out:
# Ingrese el nombre del alumno nº1: Aldi
# Ingrese 1ª nota del alumno Aldi: 6
# Ingrese 2ª nota del alumno Aldi: 10
# Ingrese 3ª nota del alumno Aldi: 8
# Ingrese el nombre del alumno nº2: Bren
# Ingrese 1ª nota del alumno Bren: 4
# Ingrese 2ª nota del alumno Bren: 7
# Ingrese 3ª nota del alumno Bren: 7
# Ingrese el nombre del alumno nº3: Cris
# Ingrese 1ª nota del alumno Cris: -1
# Ingrese 2ª nota del alumno Cris: 11
# Ingrese 3ª nota del alumno Cris: 20
# Ingrese las 3 notas validas de 0 a 10
# Ingrese 1ª nota del alumno Cris: 9
# Ingrese 2ª nota del alumno Cris: 6
# Ingrese 3ª nota del alumno Cris: 3
#
# Aldi
# Bren
# Cris
#
# Alumno:  Aldi
# Mejor nota:  10.0
# Promedio de las 3 notas:  8.0
# Alumno:  Bren
# Mejor nota:  7.0
# Promedio de las 3 notas:  6.0
# Alumno:  Cris
# Mejor nota:  9.0
# Promedio de las 3 notas:  6.0
#
# Ingrese la cantidad de elementos que tendra la lista 1: 2
# Ingrese el elemento para la lista 1: 5.5
# Ingrese el elemento para la lista 1: 10
# ...

# %% [markdown]
# 5. Se quiere cargar los nombres y notas de tres parciales de los alumnos.
#
# Para ello se propone usar un diccionario que como clave tenga el nombre del alumno y como valores una lista para las notas de los parciales-.
#
# Crear un menú como el siguiente:
#
# 1) Cargar alumno y notas
#
# 2) Mostrar el nombre y promedio mas alto.
#
# S o S) Salir.-
#
# OBS.
#
# •	No deben existir dos nombres iguales, hay que validar y solicitar reingreso si se da esa situación.
#
# •	Las notas deben pertenecer a [0,10] si no es el caso solicitar reingreso.
#
# •	Ver que no puedo ejecutar el punto 2 si al menos no ejecute el punto 1.

# %%
estudiantes={}
opcion="0"
bandera_opcion=0
while opcion!="S" and opcion!="S)":
  print("MENÚ:")
  print("1) Cargar alumno y notas")
  print("2) Mostrar el nombre y promedio mas alto")
  print("S o S) Salir")
  opcion=input("Ingrese una opción: ")
  if opcion=="1" or opcion=="1)":
    bandera_opcion=1
    bandera=0
    nombre=input("Ingrese el nombre del estudiante: ")
    for i in estudiantes:
      if i==nombre:
        print("El estudiante ya se ha cargado.")
        bandera=1
    if bandera==0:
      notas=[]
      for j in range(3):
        bandera2=0
        while bandera2==0:
          nota=float(input(f"Ingrese la {j+1}° nota del estudiante {nombre}: "))
          if nota < 0 or nota > 10:
            print("Ingrese una nota válida entre 0 y 10.")
          else:
            bandera2=1
        notas.append(nota)
      estudiantes[nombre]=notas
  if opcion=="2" or opcion=="2)":
    if bandera_opcion==0:
      print("Ejecutar el punto 1 primero.")
    else:
      promedio_mas_alto=0
      for i in estudiantes:
        suma=0
        for j in range(3):
          suma+=estudiantes[i][j]
        promedio=suma/3
        if promedio > promedio_mas_alto:
          promedio_mas_alto=promedio
          estudiante_mas_alto=i
      print("El promedio más alto es", promedio_mas_alto, "y lo tiene", estudiante_mas_alto)
# Out:
# MENÚ:
# 1) Cargar alumno y notas
# 2) Mostrar el nombre y promedio mas alto
# S o S) Salir
# Ingrese una opción: 2
# Ejecutar el punto 1 primero.
# MENÚ:
# 1) Cargar alumno y notas
# 2) Mostrar el nombre y promedio mas alto
# S o S) Salir
# Ingrese una opción: 1
# Ingrese el nombre del estudiante: Alberto
# Ingrese la 1° nota del estudiante Alberto: 11
# Ingrese una nota válida entre 0 y 10.
# Ingrese la 1° nota del estudiante Alberto: -1
# Ingrese una nota válida entre 0 y 10.
# Ingrese la 1° nota del estudiante Alberto: 10
# Ingrese la 2° nota del estudiante Alberto: 6
# Ingrese la 3° nota del estudiante Alberto: 8.5
# MENÚ:
# 1) Cargar alumno y notas
# 2) Mostrar el nombre y promedio mas alto
# S o S) Salir
# Ingrese una opción: 1
# Ingrese el nombre del estudiante: Marina
# Ingrese la 1° nota del estudiante Marina: 4
# Ingrese la 2° nota del estudiante Marina: 9
# Ingrese la 3° nota del estudiante Marina: 6
# MENÚ:
# 1) Cargar alumno y notas
# ...

# %% [markdown]
# Solución de Damián:

# %%
valido = False
alumnos = {}
calificaciones = []
menu = input("Bienvenidos al registro de usuarios, seleccione la opcion que desee: \n [1] Cargar alumno y notas \n [2] Mostrar el nombre y promedio \n [S] Salir \n\n")
while menu.upper() != "S": # al no validar el input, hago que corte solo al presionar s o S

    if menu == "1": # si elijo la opcion 1 hace esto
        clave = str(input("Ingrese el nombre del alumno: "))
        while not valido: # mientras valido sea false se ejecuta el bucle
            nota1 = float(input("Ingrese 1ª nota del alumno " + clave + ": "))
            nota2 = float(input("Ingrese 2ª nota del alumno " + clave + ": "))
            nota3 = float(input("Ingrese 3ª nota del alumno " + clave + ": "))
            if 0 <= nota1 <= 10 and 0 <= nota2 <= 10 and 0 <= nota3 <= 10: # valida que la nota este entre 0 y 10
                valido = True # cambio el valor de valido que es la variable bandera para salir del bucle
                print("Notas cargadas con exito")
                print()
            else:
                print("Ingrese las 3 notas validas de 0 a 10")
        notas = [nota1,nota2,nota3] # guardo las notas en la lista
        prom_nota = (nota1 + nota2 + nota3)/3 # calculo el promedio de las 3 notas podria usar--> sum(notas) / len(notas) si no supiera cuantas notas son
        max_nota = max(notas) # calcula el maximo de las 3 notas
        calificaciones.append(notas) # carga la lista
        alumnos[clave]= {"Notas":notas, "Mayor":max_nota, "Promedio":prom_nota} # agrega el elemento notas y la mayor de ellas al diccionario
        valido= False
        print()

    elif menu == "2": # si elijo la opcion 2 hace esto
        for alumno, detalles in alumnos.items():
            print("Alumno: ", alumno)
            print("Promedio de las 3 notas: ", detalles["Promedio"])
            print() # linea vacia

    else: # si presiono cualquier otra tecla que no sea 1,2,s o Ss
        print("Ingreso incorrecto, intente nuevamente")
        print()
    menu = input("Bienvenidos al registro de usuarios, seleccione la opcion que desee: \n [1] Cargar alumno y notas \n [2] Mostrar el nombre y promedio \n [S] Salir \n\n")
print()
print("Terminando programa...")
print()
# Out:
# Bienvenidos al registro de usuarios, seleccione la opcion que desee:
#  [1] Cargar alumno y notas
#  [2] Mostrar el nombre y promedio
#  [S] Salir
#
# 2
# Bienvenidos al registro de usuarios, seleccione la opcion que desee:
#  [1] Cargar alumno y notas
#  [2] Mostrar el nombre y promedio
#  [S] Salir
#
# 1
# Ingrese el nombre del alumno: Aldi
# Ingrese 1ª nota del alumno Aldi: 6
# Ingrese 2ª nota del alumno Aldi: 10
# Ingrese 3ª nota del alumno Aldi: 8
# Notas cargadas con exito
#
#
# Bienvenidos al registro de usuarios, seleccione la opcion que desee:
#  [1] Cargar alumno y notas
#  [2] Mostrar el nombre y promedio
#  [S] Salir
#
# 1
# Ingrese el nombre del alumno: Bren
# Ingrese 1ª nota del alumno Bren: 4
# Ingrese 2ª nota del alumno Bren: 7
# Ingrese 3ª nota del alumno Bren: 7
# Notas cargadas con exito
#
#
# Bienvenidos al registro de usuarios, seleccione la opcion que desee:
#  [1] Cargar alumno y notas
#  [2] Mostrar el nombre y promedio
#  [S] Salir
#
# 1
# ...
