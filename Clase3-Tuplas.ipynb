# %% [markdown]
# # CLASE 3 - TUPLAS

# %% [markdown]
# ## PRIMEROS EJERCICIOS

# %% [markdown]
# EJERCICIO 1:
#
# Definir una tupla llamada “letras” con las primeras 6 letras del abecedario (en minúscula) por separado, es decir, cada letra es un elemento . Luego:
#
# ▪ Mostrar todos los elementos

# %%
letras=("a","b","c","d","e","f")
for i in letras:
  print(i)
# Out:
# a
# b
# c
# d
# e
# f

# %% [markdown]
# ▪ Mostrar todos los elementos del 2do al ultimo

# %%
for i in range(1,len(letras)):
  print(letras[i])
# Out:
# b
# c
# d
# e
# f

# %% [markdown]
# ▪ Mostrar todos los elementos del 1ro al 4to

# %%
for i in range(4):
  print(letras[i])
# Out:
# a
# b
# c
# d

# %% [markdown]
# ▪ Mostrar todos los elementos del 3ro al 5to

# %%
for i in range(2,5):
  print(letras[i])
# Out:
# c
# d
# e

# %% [markdown]
# ▪ “Modificar” la tupla y cambiar las letras de minúsculas a mayúsculas

# %%
lista=[]
for i in letras:
  lista.append(i.upper())
print(tuple(lista))
# Out:
# ('A', 'B', 'C', 'D', 'E', 'F')

# %% [markdown]
# ▪ Comprobar si existe en la tupla la letra con la que comienza tu nombre

# %%
inicial=input("Ingrese su inicial: ")
if letras.count(inicial)!=0:
  print("Tu inicial está en la tupla.")
else:
  print("Tu inicial no está en la tupla.")
# Out:
# Ingrese su inicial: a
# Tu inicial está en la tupla.

# %% [markdown]
# ▪ Determinar la cantidad de elementos de la tupla con la función len()

# %%
print(len(letras))
# Out:
# 6

# %% [markdown]
# ▪ Definir otra tupla “letras2” con las próximas 3 letras (en minúsculas)

# %%
letras2=("g","h","i")

# %% [markdown]
# ▪ Unir “letras” y “letras2” en una sola tupla llamada “letras3”

# %%
letras3=letras+letras2

# %% [markdown]
# Mostrar las 3 tuplas por pantalla

# %%
print(letras)
print(letras2)
print(letras3)
# Out:
# ('a', 'b', 'c', 'd', 'e', 'f')
# ('g', 'h', 'i')
# ('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i')

# %% [markdown]
# EJERCICIO 2:
#
# Definir la tupla “números” con los siguientes números enteros:
#
# ▪ 7, 5, 2, 3, 4, 8, 6, 9, 2
#
# Buscar y mostrar por pantalla el máximo valor y su posición en la lista utilizando max() e index(). ¿Qué sucede si quiero hacer lo mismo para obtener el menor valor y su ubicación? Contar y mostrar por pantalla la cantidad de veces que aparece el numero 2 con count()

# %%
numeros=(7, 5, 2, 3, 4, 8, 6, 9, 2)
maximo=max(numeros)
print(f"El máximo valor es {maximo} y se encuentra en la posición {numeros.index(maximo)}.")
minimo=min(numeros)
print(f"El máximo valor es {minimo} y se encuentra en la posición {numeros.index(minimo)}.")
print(f"La cantidad de veces que aparece el número 2 es {numeros.count(2)}.")
# Out:
# El máximo valor es 9 y se encuentra en la posición 7.
# El máximo valor es 2 y se encuentra en la posición 2.
# La cantidad de veces que aparece el número 2 es 2.

# %% [markdown]
# ## MÁS EJERCICIOS

# %% [markdown]
# 1. Escribir un programa diaSiguienteE que dada una fecha expresada como la terna (Día, Mes, Año) (donde Día, Mes y Año son números enteros) calcule el día siguiente al dado, en el mismo formato.

# %%
fecha=(6,6,1991)
if fecha[0]==31 and fecha[1]!=12:
   diaSiguienteE=[1,fecha[1]+1,fecha[2]]
elif fecha[0]==31:
   diaSiguienteE=[1,1,fecha[2]+1]
elif fecha[0]==30 and (fecha[1]==4 or fecha[1]==6 or fecha[1]==9 or fecha[1]==11):
   diaSiguienteE=[1,fecha[1]+1,fecha[2]]
elif fecha[0]==29 and fecha[1]==2:
   diaSiguienteE=[1,3,fecha[2]]
elif fecha[0]==28 and fecha[1]==2 and fecha[2] % 4 == 0:
   diaSiguienteE=[29,2,fecha[2]]
elif fecha[0]==28 and fecha[1]==2:
   diaSiguienteE=[1,3,fecha[2]]
else:
   diaSiguienteE=[fecha[0]+1,fecha[1],fecha[2]]
print(tuple(diaSiguienteE))
# Out:
# (7, 6, 1991)

# %% [markdown]
# 2. Escribir un programa diaSiguienteT que dada una fecha expresada como la terna (Día, Mes, Año) (donde Día y Año son números enteros, y Mes es el texto Ene, Feb, ..., Dic, según corresponda) calcule el día siguiente al dado, en el mismo formato.

# %%
fecha=(6,"Jun",1991)
if fecha[0]==31 and fecha[1]=="Ene":
  diaSiguienteT=[1,"Feb",fecha[2]]
elif fecha[0]==29 and fecha[1]=="Feb":
  diaSiguienteT=[1,"Mar",fecha[2]]
elif fecha[0]==28 and fecha[1]=="Feb" and fecha[2] % 4 == 0:
  diaSiguienteT=[29,"Feb",fecha[2]]
elif fecha[0]==28 and fecha[1]=="Feb":
  diaSiguienteT=[1,"Mar",fecha[2]]
elif fecha[0]==31 and fecha[1]=="Mar":
  diaSiguienteT=[1,"Abr",fecha[2]]
elif fecha[0]==30 and fecha[1]=="Abr":
  diaSiguienteT=[1,"May",fecha[2]]
elif fecha[0]==31 and fecha[1]=="May":
  diaSiguienteT=[1,"Jun",fecha[2]]
elif fecha[0]==30 and fecha[1]=="Jun":
  diaSiguienteT=[1,"Jul",fecha[2]]
elif fecha[0]==31 and fecha[1]=="Jul":
  diaSiguienteT=[1,"Ago",fecha[2]]
elif fecha[0]==31 and fecha[1]=="Ago":
  diaSiguienteT=[1,"Sep",fecha[2]]
elif fecha[0]==30 and fecha[1]=="Sep":
  diaSiguienteT=[1,"Oct",fecha[2]]
elif fecha[0]==31 and fecha[1]=="Oct":
  diaSiguienteT=[1,"Nov",fecha[2]]
elif fecha[0]==30 and fecha[1]=="Nov":
  diaSiguienteT=[1,"Dic" by,fecha[2]]
elif fecha[0]==31:
  diaSiguienteT=[1,"Ene",fecha[2]+1]
else:
  diaSiguienteT=[fecha[0]+1,fecha[1],fecha[2]]
print(tuple(diaSiguienteT))
# Out:
# (7, 'Jun', 1991)

# %% [markdown]
# 3. Escribir un programa que defina una tupla de elementos e indique si se encuentran ordenados de menor a mayor o no.

# %%
tupla=(1,2,3,7,50,40)
bandera=0
for i in range(len(tupla)-1):
  print(tupla[i+1])
  if tupla[i]>tupla[i+1]:
    bandera=1
    break
if bandera==1:
  print("Los elementos no se encuentran ordenados de menor a mayor.")
else:
  print("Los elementos se encuentran ordenados de menor a mayor.")
# Out:
# 2
# 3
# 7
# 50
# 40
# Los elementos no se encuentran ordenados de menor a mayor.

# %% [markdown]
# Solución de Martín:

# %%
tupla1 = 1, 2, 4, 3, 5, 7, 3
tupla2 = 1, 3, 4, 5, 6
tupla3 = 1, 5, 'A', 'T', 'g', 'z'
tupla4 = 2, 'P', 'terpeno'
tupla5 = 'Azul', 'P', 'terpeno'
tupla6 = 'Azul', 'P', 'terpeno', 4

def estaOrdenado(tupla):
  for i in range(len(tupla)):
    if i == 0:
      item = str(tupla[i])
    else:
      if (len(item)==1 and (len(str(tupla[i]))==1) and (ord(str(item)) < ord(str(tupla[i])))):
        item = str(tupla[i])
      elif (len(item)!=1 and (len(str(tupla[i]))!=1)) and (ord(str(item[0])) < ord(str(tupla[i][0]))):
        item = str(tupla[i])
      elif (len(item)==1 and (len(str(tupla[i]))!=1)) and (ord(str(item)) < ord(str(tupla[i][0]))):
        item = str(tupla[i])
      elif (len(item)!=1 and (len(str(tupla[i]))==1)) and (ord(str(item[0])) < ord(str(tupla[i]))):
        item = str(tupla[i])
      else:
        return (print('No está ordenado'))
  return(print('Esta ordenado'))

estaOrdenado(tupla1)
estaOrdenado(tupla2)
estaOrdenado(tupla3)
estaOrdenado(tupla4)
estaOrdenado(tupla5)
estaOrdenado(tupla6)
# Out:
# No está ordenado
# Esta ordenado
# Esta ordenado
# Esta ordenado
# Esta ordenado
# No está ordenado

# %% [markdown]
# 4. Dada una tupla de números enteros, escribir un programa que:
#
#  a) cree una tupla con todos los que sean primos.
#  b) cree una tupla con la sumatoria y el promedio de los valores.
#  c) cree una tupla con el factorial de cada uno de esos números.

# %%
tupla=(10,17,11,23,16)

lista_primos=[]
for i in tupla:
  bandera=0
  for n in range(2,i):
    if i % n == 0:
      bandera=1
  if bandera==0:
    lista_primos.append(i)
tupla_primos=tuple(lista_primos)
print(f"a) Los primos son {tupla_primos}.")

sumatoria=0
for i in tupla:
  sumatoria+=i
promedio=sumatoria/len(tupla)
print(f"b) La sumatoria es {sumatoria} y el promedio es {promedio}.")

lista_factoriales=[]
for i in tupla:
  factorial=1
  for j in range(2,i+1):
    factorial=factorial*j
  lista_factoriales.append(factorial)
tupla_factoriales=tuple(lista_factoriales)
print(f"c) Los factoriales son {tupla_factoriales}.")
# Out:
# a) Los primos son (17, 11, 23).
# b) La sumatoria es 77 y el promedio es 15.4.
# c) Los factoriales son (3628800, 355687428096000, 39916800, 25852016738884976640000, 20922789888000).

# %% [markdown]
# 5. Escribir un programa que a partir de una lista de tuplas (Apellido, Nombre, Inicial_segundo_nombre) cree una lista de cadenas donde cada una contenga primero el nombre, luego la inicial con un punto, y luego el apellido.

# %%
lista=[("Ferrari", "Alberto", "J"),("Gómez", "Celina", "V"),("Fernández", "Marina", "L"),("Ferrari","Jorge","L")]
lista_nueva=[]
for i in range(len(lista)):
  lista_nueva.append(f"{lista[i][1]} {lista[i][2]}. {lista[i][0]}")
print(lista_nueva)
# Out:
# ['Alberto J. Ferrari', 'Celina V. Gómez', 'Marina L. Fernández', 'Jorge L. Ferrari']
